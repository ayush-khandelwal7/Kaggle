# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
RatingsDict = {
    "Ex":5,
    "Gd":4,
    "TA":3,
    "Fa":2,
    "Po":1,
    "NA":0
}

BsmtExposureDict = {
    "Gd":4,
    "Av":3,
    "Mn":2,
    "No":1,
    "NA":0
}

BsmntFinDict = {
    "GLQ":6,
    "ALQ":5,
    "BLQ":4,
    "Rec":3,
    "LwQ":2,
    "Unf":1,
    "NA":0
}

GarageFinishDict = {
    "Fin":3,
    "RFn":2,
    "Unf":1,
    "NA":0
}

PavedDriveDict = {
    "Y":2,
    "P":1,
    "N":0
}

FenceDict = {
    "GdPrv":4,
    "MnPrv":3,
    "GdWo":2,
    "MnWw":1,
    "NA":0
}

# %%
def applyRatings(x):
    x = RatingsDict[x]
    return x

def applyBsmtExp(x):
    x = BsmtExposureDict[x]
    return x

def applyBsmntFin(x):
    x = BsmntFinDict[x]
    return x

def applyGarage(x):
    x = GarageFinishDict[x]
    return x

def applyPaved(x):
    x = PavedDriveDict[x]
    return x

def applyFence(x):
    x = FenceDict[x]
    return x

# %%
def preprocess(df):
    df.MSSubClass = df.MSSubClass.astype('category')
    df.ExterQual = df.ExterQual.fillna('NA')
    df.ExterQual = df.ExterQual.apply(applyRatings)
    df.ExterCond = df.ExterCond.apply(applyRatings)
    
    df.BsmtQual = df.BsmtQual.fillna('NA')
    df.BsmtQual = df.BsmtQual.apply(applyRatings)
    df.BsmtCond = df.BsmtCond.fillna('NA')
    df.BsmtCond = df.BsmtCond.apply(applyRatings)
    df.BsmtExposure = df.BsmtExposure.fillna('NA')
    df.BsmtExposure = df.BsmtExposure.apply(applyBsmtExp)
    df.BsmtFinType1 = df.BsmtFinType1.fillna('NA')
    df.BsmtFinType1 = df.BsmtFinType1.apply(applyBsmntFin)
    df.BsmtFinType2 = df.BsmtFinType2.fillna('NA')
    df.BsmtFinType2 = df.BsmtFinType2.apply(applyBsmntFin)
    
    df.HeatingQC = df.HeatingQC.apply(applyRatings)
    df.KitchenQual = df.KitchenQual.fillna('NA')
    df.KitchenQual = df.KitchenQual.apply(applyRatings)
    df.FireplaceQu = df.FireplaceQu.fillna('NA')
    df.FireplaceQu = df.FireplaceQu.apply(applyRatings)
    
    df.GarageFinish = df.GarageFinish.fillna('NA')
    df.GarageFinish = df.GarageFinish.apply(applyGarage)
    df.GarageQual = df.GarageQual.fillna('NA')
    df.GarageQual = df.GarageQual.apply(applyRatings)
    df.GarageCond = df.GarageCond.fillna('NA')
    df.GarageCond = df.GarageCond.apply(applyRatings)
    
    df.PavedDrive = df.PavedDrive.apply(applyPaved)
    df.PoolQC = df.PoolQC.fillna('NA')
    df.PoolQC = df.PoolQC.apply(applyRatings)
    df.Fence = df.Fence.fillna('NA')
    df.Fence = df.Fence.apply(applyFence)
    
    df.LotFrontage = df.LotFrontage.fillna(0)
    df.MasVnrType = df.MasVnrType.fillna("None")
    df.MasVnrArea = df.MasVnrArea.fillna(0)
    df.GarageType = df.GarageType.fillna("NA")
    
    del df['Alley']
    del df['MiscFeature']
    del df['MiscVal']
    del df['GarageYrBlt']
    
    #df = df.dropna()
    
    #del df['YrSold']
    X = df.copy()
    del X['Id']
    #del X['SalePrice']
    X = pd.get_dummies(X)
    #y = df['SalePrice']
    #return X,y
    return X

# %%
X,y = preprocess(df)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
preds = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y, preds)
# Out:
# 505668074.7687458

# %%
#https://scikit-learn.org/stable/modules/linear_model.html

# %%
from sklearn.linear_model import RidgeCV

# %%
model = RidgeCV(alphas=[.5,.1,0.01,1,10], cv=3)

# %%
model.fit(X,y)
# Out:
# RidgeCV(alphas=[0.5, 0.1, 0.01, 1, 10], cv=3, fit_intercept=True,
#     gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)

# %%
preds = model.predict(X)
mean_squared_error(y, preds)
# Out:
# 709314127.6908009

# %%
model.alpha_
# Out:
# 10

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso(alpha=0.1)

# %%
model.fit(X,y)
# Out:
# C:\Users\ayush\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
preds = model.predict(X)
mean_squared_error(y, preds)
# Out:
# 505669116.83644366

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state=0)

# %%
model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
preds = model.predict(X)
mean_squared_error(y, preds)
# Out:
# 0.0

# %%
model.feature_importances_
# Out:
# array([6.48864326e-03, 7.08418596e-03, 6.36149478e-01, 3.10696719e-03,
#        1.31211350e-02, 4.88250841e-03, 2.76692114e-03, 2.49162067e-03,
#        1.17411139e-03, 7.99720218e-04, 2.80283708e-04, 2.03564436e-03,
#        2.65795545e-03, 2.82899820e-02, 1.13302101e-05, 6.20027095e-04,
#        6.67524027e-03, 3.01866039e-02, 3.80842616e-04, 1.78383321e-02,
#        3.75819954e-02, 9.30272153e-05, 9.75443875e-02, 2.27878345e-04,
#        2.13484551e-06, 2.38837699e-03, 3.50244504e-04, 5.53956294e-04,
#        5.81680658e-03, 2.26357133e-03, 1.90961376e-03, 7.53865927e-04,
#        5.52408864e-04, 1.86273011e-03, 2.29949736e-02, 9.89511635e-03,
#        1.59212972e-03, 9.94165700e-06, 4.65496883e-04, 2.80592347e-03,
#        1.84416768e-03, 1.28455518e-03, 0.00000000e+00, 1.37097123e-04,
#        3.38899993e-04, 2.17208776e-07, 1.22205020e-04, 4.69106547e-03,
#        2.09632949e-04, 3.47534042e-06, 0.00000000e+00, 5.43021940e-08,
# ...

# %%
testdata = pd.read_csv('test.csv')

# %%
Ids = testdata['Id']

# %%
X_test = preprocess(testdata)

# %%
X, X_test = X.align(X_test, join='left', axis=1)

# %%
X.head()
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    MasVnrArea  ExterQual  ExterCond  BsmtQual          ...            \
# 0       196.0          4          3         4          ...
# 1         0.0          3          3         4          ...
# 2       162.0          4          3         4          ...
# 3         0.0          3          3         3          ...
# 4       350.0          4          3         4          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
X_test.head()
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         80.0    11622            5            6       1961          1961
# 1         81.0    14267            6            6       1958          1958
# 2         74.0    13830            5            5       1997          1998
# 3         78.0     9978            6            6       1998          1998
# 4         43.0     5005            8            5       1992          1992
#
#    MasVnrArea  ExterQual  ExterCond  BsmtQual          ...            \
# 0         0.0          3          3         3          ...
# 1       108.0          3          3         3          ...
# 2         0.0          3          3         4          ...
# 3        20.0          3          3         3          ...
# 4         0.0          4          3         4          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
X_test = X_test.fillna(0)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 240 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(25), int64(38), uint8(177)
# memory usage: 970.4 KB

# %%
preds = model.predict(X_test)

# %%
len(preds)
# Out:
# 1459

# %%
Ids
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
# 5       1466
# 6       1467
# 7       1468
# 8       1469
# 9       1470
# 10      1471
# 11      1472
# 12      1473
# 13      1474
# 14      1475
# 15      1476
# 16      1477
# 17      1478
# 18      1479
# 19      1480
# 20      1481
# 21      1482
# 22      1483
# 23      1484
# 24      1485
# 25      1486
# 26      1487
# 27      1488
# 28      1489
# 29      1490
#         ...
# 1429    2890
# 1430    2891
# 1431    2892
# 1432    2893
# 1433    2894
# 1434    2895
# 1435    2896
# 1436    2897
# 1437    2898
# 1438    2899
# 1439    2900
# 1440    2901
# 1441    2902
# 1442    2903
# 1443    2904
# 1444    2905
# 1445    2906
# 1446    2907
# 1447    2908
# 1448    2909
# 1449    2910
# 1450    2911
# 1451    2912
# 1452    2913
# 1453    2914
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
out = pd.DataFrame({'Id':Ids, 'SalePrice':preds})

# %%
out
# Out:
#         Id  SalePrice
# 0     1461   127500.0
# 1     1462   155000.0
# 2     1463   192000.0
# 3     1464   178000.0
# 4     1465   212000.0
# 5     1466   177000.0
# 6     1467   141000.0
# 7     1468   177000.0
# 8     1469   184900.0
# 9     1470   145000.0
# 10    1471   185000.0
# 11    1472    83000.0
# 12    1473    75000.0
# 13    1474   148500.0
# 14    1475   139400.0
# 15    1476   611657.0
# 16    1477   235128.0
# 17    1478   320000.0
# 18    1479   228000.0
# 19    1480   412500.0
# 20    1481   285000.0
# 21    1482   202500.0
# 22    1483   186000.0
# 23    1484   196000.0
# 24    1485   180000.0
# 25    1486   225000.0
# 26    1487   538000.0
# 27    1488   252000.0
# 28    1489   250580.0
# 29    1490   218000.0
# ...    ...        ...
# 1429  2890    80000.0
# 1430  2891   133000.0
# 1431  2892    34900.0
# 1432  2893   137500.0
# 1433  2894    40000.0
# 1434  2895   392500.0
# 1435  2896   235000.0
# 1436  2897   168000.0
# 1437  2898   143000.0
# ...

# %%
out.to_csv('output.csv', index=False)
